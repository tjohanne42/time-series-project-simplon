# %% [markdown]
# <a href="https://colab.research.google.com/github/tjohanne42/time_series_project_simplon/blob/main/time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/tjohanne42/time_series_project_simplon.git
# !pip install darts
# !pip install keras-tcn
# Out:
# fatal: destination path 'time_series_project_simplon' already exists and is not an empty directory.
# Requirement already satisfied: darts in /usr/local/lib/python3.7/dist-packages (0.12.0)
# Requirement already satisfied: torch<1.9.0,>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from darts) (1.8.1)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from darts) (1.0.1)
# Requirement already satisfied: tensorboard>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from darts) (2.6.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.7/dist-packages (from darts) (1.19.5)
# Requirement already satisfied: ipython>=7.22.0 in /usr/local/lib/python3.7/dist-packages (from darts) (7.28.0)
# Requirement already satisfied: lightgbm>=3.2.1 in /usr/local/lib/python3.7/dist-packages (from darts) (3.3.0)
# Requirement already satisfied: tqdm>=4.60.0 in /usr/local/lib/python3.7/dist-packages (from darts) (4.62.3)
# Requirement already satisfied: pandas<1.3.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from darts) (1.2.5)
# Requirement already satisfied: pystan<3.0.0.0,>=2.19.1.1 in /usr/local/lib/python3.7/dist-packages (from darts) (2.19.1.1)
# Requirement already satisfied: pmdarima>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from darts) (1.8.3)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.7/dist-packages (from darts) (2.26.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from darts) (1.7.1)
# Requirement already satisfied: statsmodels>=0.12.0 in /usr/local/lib/python3.7/dist-packages (from darts) (0.13.0)
# Requirement already satisfied: filterpy>=1.4.5 in /usr/local/lib/python3.7/dist-packages (from darts) (1.4.5)
# Requirement already satisfied: scikit-learn<1.0.0,>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from darts) (0.24.2)
# Requirement already satisfied: matplotlib>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from darts) (3.4.3)
# Requirement already satisfied: holidays>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from darts) (0.11.3.1)
# Requirement already satisfied: prophet>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from darts) (1.0.1)
# Requirement already satisfied: xarray>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from darts) (0.18.2)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.7/dist-packages (from holidays>=0.11.0->darts) (0.2.1)
# Requirement already satisfied: convertdate>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from holidays>=0.11.0->darts) (2.3.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from holidays>=0.11.0->darts) (2.8.2)
# Requirement already satisfied: hijri-converter in /usr/local/lib/python3.7/dist-packages (from holidays>=0.11.0->darts) (2.2.2)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.7/dist-packages (from convertdate>=2.3.0->holidays>=0.11.0->darts) (2018.9)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.7/dist-packages (from convertdate>=2.3.0->holidays>=0.11.0->darts) (0.5.11)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=7.22.0->darts) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=7.22.0->darts) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.22.0->darts) (5.1.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.7/dist-packages (from ipython>=7.22.0->darts) (0.1.3)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.22.0->darts) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.22.0->darts) (0.18.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=7.22.0->darts) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.22.0->darts) (57.4.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.22.0->darts) (3.0.20)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=7.22.0->darts) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython>=7.22.0->darts) (0.8.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=3.2.1->darts) (0.37.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.0->darts) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.0->darts) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.0->darts) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.0->darts) (1.3.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib>=3.4.0->darts) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython>=7.22.0->darts) (0.7.0)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima>=1.8.0->darts) (0.29.24)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima>=1.8.0->darts) (1.24.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.22.0->darts) (0.2.5)
# Requirement already satisfied: cmdstanpy==0.9.68 in /usr/local/lib/python3.7/dist-packages (from prophet>=1.0.0->darts) (0.9.68)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.7/dist-packages (from prophet>=1.0.0->darts) (0.0.9)
# Requirement already satisfied: setuptools-git>=1.2 in /usr/local/lib/python3.7/dist-packages (from prophet>=1.0.0->darts) (1.2)
# Requirement already satisfied: ujson in /usr/local/lib/python3.7/dist-packages (from cmdstanpy==0.9.68->prophet>=1.0.0->darts) (4.2.0)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.7/dist-packages (from LunarCalendar>=0.0.9->prophet>=1.0.0->darts) (4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->darts) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->darts) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->darts) (2.0.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<1.0.0,>=0.24.0->darts) (3.0.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.12.0->darts) (0.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.4.0->darts) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.4.0->darts) (3.3.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.4.0->darts) (0.12.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.4.0->darts) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.4.0->darts) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.4.0->darts) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.4.0->darts) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.4.0->darts) (1.41.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.4.0->darts) (3.17.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.4.0->darts) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.4.0->darts) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.4.0->darts) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.0->darts) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.4.0->darts) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.4.0->darts) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.0->darts) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch<1.9.0,>=1.8.0->darts) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard>=2.4.0->darts) (3.6.0)
# Requirement already satisfied: keras-tcn in /usr/local/lib/python3.7/dist-packages (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-tcn) (1.19.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from keras-tcn) (2.6.0)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.7/dist-packages (from keras-tcn) (0.14.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (0.12.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (2.6.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (3.7.4.3)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (5.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (3.17.3)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (2.6.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (1.12)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (1.1.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (3.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (1.1.2)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (1.41.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (0.4.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (1.15.0)
# Requirement already satisfied: keras~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-tcn) (2.6.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow->keras-tcn) (1.5.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->keras-tcn) (57.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->keras-tcn) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->keras-tcn) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->keras-tcn) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->keras-tcn) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->keras-tcn) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->keras-tcn) (2.26.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->keras-tcn) (1.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow->keras-tcn) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow->keras-tcn) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow->keras-tcn) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-tcn) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow->keras-tcn) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow->keras-tcn) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-tcn) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-tcn) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-tcn) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-tcn) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-tcn) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow->keras-tcn) (3.6.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->keras-tcn) (2.7.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import time
import math
import copy

from time_series_project_simplon.utils.functions import generate_df_by_time_section
from time_series_project_simplon.utils import functions

from darts import TimeSeries
from darts.models import (
    NaiveSeasonal,
    NaiveDrift,
    Prophet,
    ExponentialSmoothing,
    ARIMA,
    AutoARIMA,
    Theta
)
from darts.metrics import mape, mase, mae, mse, ope, rmse, rmsle
from darts.metrics import r2_score as darts_r2_score
from darts.utils.statistics import check_seasonality, plot_acf, plot_residuals_analysis
from darts.dataprocessing.transformers.boxcox import BoxCox


from darts.datasets import AirPassengersDataset, AusBeerDataset, GasRateCO2Dataset 
from darts.datasets import HeartRateDataset, IceCreamHeaterDataset, MonthlyMilkDataset
from darts.datasets import SunspotsDataset

from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

from tcn import TCN

# %% [markdown]
# # I. Load data

# %%
df_raw = generate_df_by_time_section(time_section="day", verbose=True)
df_raw.tail()
# Out:
# replace outliers in 'solar' values with interpolation ...
# set seconds, minutes and hours to 0 ...
#   0%|          | 0/796411 [00:00<?, ?it/s]
# get the mean values for every day ...
# multiply all values by 12 * 24 to get the actual values by day ...
# done
#       timestamp  coal    nuclear       wind       hydro       solar
# 2767 2019-07-30   0.0  1.574e+06  1.234e+06   73637.000  376435.335
# 2768 2019-07-31   0.0  1.607e+06  1.686e+06   92945.000  355390.764
# 2769 2019-08-01   0.0  1.607e+06  6.505e+05  117124.000  519328.583
# 2770 2019-08-02   0.0  1.592e+06  2.959e+05  115334.000  596295.100
# 2771 2019-08-03   0.0  1.567e+06  1.845e+05   90230.519  607272.596

# %% [markdown]
# # II. Darts for the men, Darts for the girls

# %%
col = "nuclear"
time_col = "timestamp"
df_for_darts = copy.deepcopy(df_raw)

# %%
# for col "solar" only
# for i in df_for_darts.index:
#   if df_for_darts["solar"][i] > 0.0:
#     break
# df_for_darts = df_for_darts.iloc[i+1:]
# df_for_darts.reset_index(drop=True, inplace=True)
# df_for_darts["solar"][df_for_darts["solar"] <= 0.0] = 0.1
# df_for_darts[df_for_darts["solar"] <= 0.0]

# %%
series = df_for_darts[col]
series.index = df_for_darts[time_col]
series = pd.DataFrame(series)
print("size null values:", len(series[series[col] == 0.0]))
series = series.replace(0, 0.1)
print("size null values:", len(series[series[col] == 0.0]))
series = TimeSeries.from_dataframe(series)
# Out:
# size null values: 0
# size null values: 0

# %%
# seasonality
ALPHA = 0.05

for m in range(2, 25):
    is_seasonal, mseas = check_seasonality(series, m=m, alpha=ALPHA)
    if is_seasonal:
        break

print("seasonal? " + str(is_seasonal))
if is_seasonal:
    print('There is seasonality of order {}.'.format(mseas))
# Out:
# [2021-10-21 16:49:10,000] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,017] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,027] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,036] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,043] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,057] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,066] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,079] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,095] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,104] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,114] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,122] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,136] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,146] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,157] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,166] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,176] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,185] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,193] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,205] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,213] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,223] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# [2021-10-21 16:49:10,234] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# INFO:darts.utils.statistics:The ACF has no local maximum for m < max_lag = 24.
# seasonal? False

# %%
# train_test_split
val_size = 0.3
split_at = pd.Timestamp(df_for_darts[time_col][len(df_for_darts) - int(val_size * len(df_for_darts))])

train, val = series.split_before(split_at)

plt.figure(figsize=(12, 5))
train.plot(label='training')
val.plot(label='validation')
plt.legend();

# %%
# # prepare ARIMA forecaster # not working / TODO

# y = np.asarray(series.pd_series())
# # get order of first differencing: the higher of KPSS and ADF test results
# n_kpss = pmd.arima.ndiffs(y, alpha=ALPHA, test='kpss', max_d=2)
# n_adf = pmd.arima.ndiffs(y, alpha=ALPHA, test='adf', max_d=2)
# n_diff = max(n_adf, n_kpss)

# # get order of seasonal differencing: the higher of OCSB and CH test results
# n_ocsb = pmd.arima.OCSBTest(m=max(4,mseas)).estimate_seasonal_differencing_term(y)
# n_ch = pmd.arima.CHTest(m=max(4,mseas)).estimate_seasonal_differencing_term(y)
# ns_diff = max(n_ocsb, n_ch, is_seasonal * 1)

# # set up the ARIMA forecaster
# m_arima = AutoARIMA(
#     start_p=1, d=n_diff, start_q=1,
#     max_p=4, max_d=n_diff, max_q=4,
#     start_P=0, D=ns_diff, start_Q=0, m=max(4,mseas), seasonal=is_seasonal,
#     max_P=3, max_D=1, max_Q=3,
#     max_order=5,                       # p+q+p+Q <= max_order
#     stationary=False, 
#     information_criterion="bic", alpha=ALPHA, 
#     test="kpss", seasonal_test="ocsb",
#     stepwise=True, 
#     suppress_warnings=True, error_action="trace", trace=True, with_intercept="auto")

# %%
# prepare Theta forecaster

# search space for best theta value: check 100 alternatives
thetas = 2 - np.linspace(-10, 10, 100)

# initialize search
best_mape = float('inf')
best_theta = 0
# search for best theta among 50 values, as measured by MAPE
for theta in thetas:
    model = Theta(theta)
    res = model.fit(train)
    pred_theta = model.predict(len(val))
    # res_mape = mape(val, pred_theta)
    res_mape = rmsle(val, pred_theta)
    # res_mape = mean_absolute_percentage_error(val, pred_theta)

    if res_mape < best_mape:
        best_mape = res_mape
        best_theta = theta

m_theta = Theta(best_theta)   # best theta model among 100
# Out:
# [2021-10-21 16:49:10,880] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:10,880] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:10,983] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:10,983] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,059] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,059] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,139] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,139] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,210] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,210] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,291] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,291] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,377] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,377] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,456] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,456] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,556] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,556] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,648] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,648] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,736] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,736] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,833] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,833] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:11,928] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:11,928] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,026] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,026] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,100] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,100] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,188] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,188] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,271] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,271] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,367] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,367] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,448] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,448] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,556] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,556] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,647] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,647] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,721] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,721] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,797] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,797] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,873] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,873] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:12,957] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:12,957] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,041] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,041] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,118] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,118] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,205] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,205] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,295] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,295] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,373] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,373] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,468] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,468] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,553] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,553] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,644] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,644] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,713] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,713] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,792] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,792] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,891] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,891] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:13,979] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:13,979] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,065] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,065] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,150] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,150] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,243] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,243] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,328] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,328] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,420] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,420] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,501] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,501] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,590] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,590] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,674] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,674] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,743] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,743] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,825] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,825] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,906] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,906] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:14,988] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:14,988] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,082] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,082] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,185] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,185] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,264] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,264] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,342] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,342] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,429] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,429] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,517] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,517] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,603] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,603] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,694] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,694] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,784] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,784] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,882] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,882] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:15,968] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:15,968] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,060] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,060] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,150] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,150] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,243] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,243] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,338] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,338] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,430] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,430] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,524] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,524] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,600] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,600] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,677] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,677] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,757] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,757] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,836] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,836] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,908] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,908] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:16,997] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:16,997] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,081] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,081] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,150] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,150] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,228] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,228] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,301] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,301] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,384] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,384] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,460] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,460] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,534] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,534] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,620] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,620] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,695] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,695] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,776] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,776] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,859] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,859] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:17,942] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:17,942] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,028] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,028] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,113] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,113] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,189] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,189] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,276] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,276] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,354] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,354] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,435] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,435] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,523] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,523] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,610] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,610] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,704] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,704] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,796] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,796] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,881] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,881] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:18,972] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:18,972] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:19,055] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:19,055] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:19,143] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:19,143] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:19,235] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:19,235] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:19,319] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:19,319] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.

# %%
if is_seasonal:
    m_expon = ExponentialSmoothing(seasonal_periods=mseas)
else:
    m_expon = ExponentialSmoothing()
m_naive = NaiveDrift()
m_prophet = Prophet()

# %%
def eval_model(model):
    t_start =  time.perf_counter()
    print("beginning: " + str(model))


    # fit the model and compute predictions
    res = model.fit(train)
    forecast = model.predict(len(val))
    
    # print(forecast.values())
    

    # for naive forecast, concatenate seasonal fc with drift fc
    if model == m_naive:
        if is_seasonal:
            fc_drift = forecast
            modelS = NaiveSeasonal(K=mseas)
            modelS.fit(train)
            fc_seas = modelS.predict(len(val))
            forecast = fc_drift + fc_seas - train.last_value()

    true = val.values()
    # true = [max(x, 0.0) for x in true]
    pred = forecast.values()
    # compute accuracy metrics and processing time
    res_mape = mean_absolute_percentage_error(true, pred)
    res_mae = mean_absolute_error(true, pred)
    res_r2 = r2_score(true, pred)
    res_mse = mean_squared_error(true, pred)
    res_rmse = np.sqrt(mean_squared_error(true, pred))
    res_rmsle = np.log(np.sqrt(mean_squared_error(true, pred)))

    try:
      res_darts_mape = mape(val, forecast)
    except:
      res_darts_mape = None
    res_darts_mae = mae(val, forecast)
    res_darts_r2 = darts_r2_score(val, forecast)
    res_darts_rmse = rmse(val, forecast)
    res_darts_rmsle = rmsle(val, forecast)
    res_time = time.perf_counter() - t_start
    res_accuracy = {"MAPE": res_mape, "MAE": res_mae, "R squared": -res_r2, "MSE": res_mse, "RMSE": res_rmse, "RMSLE" :res_rmsle, "time": res_time,
                    "DARTS_MAPE": res_darts_mape, "DARTS_MAE": res_darts_mae, "DARTS_R squared": res_darts_r2, "DARTS_RMSE": res_darts_rmse,
                    "DARTS_RMSLE": res_darts_rmsle}

    results = [forecast, res_accuracy]
    print("completed: " + str(model) + ":" + str(res_time) + "sec")
    return results

models = {"prophet": m_prophet, "naive": m_naive, "expon": m_expon, "theta": m_theta}

model_predictions = [eval_model(v) for k, v in models.items()]
model_predictions
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# beginning: Prophet
# completed: Prophet:4.911826356000347sec
# beginning: Naive drift model
# completed: Naive drift model:0.08028468100019381sec
# beginning: Exponential smoothing
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# /usr/local/lib/python3.7/dist-packages/darts/metrics/metrics.py:398: RuntimeWarning:
#
# invalid value encountered in log
#
# [2021-10-21 16:49:24,991] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:24,991] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
# completed: Exponential smoothing:0.5469005909999396sec
# beginning: Theta(0.08080808080808133)
# completed: Theta(0.08080808080808133):0.13990557299985085sec
# [[<TimeSeries (DataArray) (time: 831, component: 1, sample: 1)>
#   array([[[2230765.8500261 ]],
#
#          [[2222481.28971077]],
#
#          [[2205135.23762965]],
#
#          [[2181581.27074631]],
#
#          [[2171823.9840387 ]],
#
#          [[2188958.89025106]],
#
#          [[2198099.78955287]],
#
#          [[2199834.46437321]],
#
#          [[2191255.79971123]],
#
#          [[2173705.42035316]],
#
#   ...
#
#          [[2403413.25700952]],
#
#          [[2388111.47224455]],
#
#          [[2386072.29367749]],
#
#          [[2410367.04908216]],
#
#          [[2426106.512693  ]],
#
#          [[2433894.57204084]],
#
#          [[2430856.72727083]],
#
#          [[2418380.61277418]],
#
#          [[2399344.07917837]],
#
#          [[2393790.79029094]]])
#   Coordinates:
#     * time       (time) datetime64[ns] 2017-04-25 2017-04-26 ... 2019-08-03
#     * component  (component) object 'nuclear'
#   Dimensions without coordinates: sample,
#   {'MAPE': 0.20385841416172074,
#    'MAE': 351256.8580191948,
#    'R squared': 1.6396754018969655,
#    'MSE': 194489274552.97513,
#    'RMSE': 441009.38147954986,
#    'RMSLE': 12.99682142739897,
#    'time': 4.911826356000347,
#    'DARTS_MAPE': 20.385841416172074,
#    'DARTS_MAE': 351256.8580191948,
#    'DARTS_R squared': -1.6396754018969655,
#    'DARTS_RMSE': 441009.38147954986,
#    'DARTS_RMSLE': 0.22748247623277273}],
#  [<TimeSeries (DataArray) (time: 831, component: 1, sample: 1)>
#   array([[[1985785.45927835]],
#
#          [[1985762.9185567 ]],
#
#          [[1985740.37783505]],
#
#          [[1985717.8371134 ]],
#
#          [[1985695.29639175]],
#
#          [[1985672.7556701 ]],
#
#          [[1985650.21494845]],
#
#          [[1985627.6742268 ]],
#
#          [[1985605.13350515]],
#
#          [[1985582.59278351]],
#
#   ...
#
#          [[1967279.52680412]],
#
#          [[1967256.98608247]],
#
#          [[1967234.44536082]],
#
#          [[1967211.90463918]],
#
#          [[1967189.36391753]],
#
#          [[1967166.82319588]],
#
#          [[1967144.28247423]],
#
#          [[1967121.74175258]],
#
#          [[1967099.20103093]],
#
#          [[1967076.66030928]]])
#   Coordinates:
#     * time       (time) datetime64[ns] 2017-04-25 2017-04-26 ... 2019-08-03
#     * component  (component) object 'nuclear'
#   Dimensions without coordinates: sample,
#   {'MAPE': 0.11919440361842998,
#    'MAE': 214189.62375217688,
#    'R squared': -0.022599981603207975,
#    'MSE': 72014089455.63852,
#    'RMSE': 268354.4101661803,
#    'RMSLE': 12.500063811851078,
#    'time': 0.08028468100019381,
#    'DARTS_MAPE': 11.919440361842998,
#    'DARTS_MAE': 214189.62375217688,
#    'DARTS_R squared': 0.022599981603207975,
#    'DARTS_RMSE': 268354.4101661803,
#    'DARTS_RMSLE': 0.14783681185694958}],
#  [<TimeSeries (DataArray) (time: 831, component: 1, sample: 1)>
#   array([[[ 1.97751437e+06]],
#
#          [[ 1.95883563e+06]],
#
#          [[ 1.94101712e+06]],
#
#          [[ 1.91416879e+06]],
#
#          [[ 1.90293967e+06]],
#
#          [[ 1.92471470e+06]],
#
#          [[ 1.93587934e+06]],
#
#          [[ 1.92708459e+06]],
#
#          [[ 1.90840585e+06]],
#
#          [[ 1.89058733e+06]],
#
#   ...
#
#          [[-3.95926798e+06]],
#
#          [[-3.98611630e+06]],
#
#          [[-3.99734542e+06]],
#
#          [[-3.97557040e+06]],
#
#          [[-3.96440575e+06]],
#
#          [[-3.97320051e+06]],
#
#          [[-3.99187925e+06]],
#
#          [[-4.00969776e+06]],
#
#          [[-4.03654609e+06]],
#
#          [[-4.04777521e+06]]])
#   Coordinates:
#     * time       (time) datetime64[ns] 2017-04-25 2017-04-26 ... 2019-08-03
#     * component  (component) object 'nuclear'
#   Dimensions without coordinates: sample,
#   {'MAPE': 1.6440233719756752,
#    'MAE': 2985826.13971433,
#    'R squared': 151.96296939126185,
#    'MSE': 11270195164525.262,
#    'RMSE': 3357111.1337763695,
#    'RMSLE': 15.026591380501005,
#    'time': 0.5469005909999396,
#    'DARTS_MAPE': 164.4023371975675,
#    'DARTS_MAE': 2985826.13971433,
#    'DARTS_R squared': -151.96296939126185,
#    'DARTS_RMSE': 3357111.1337763695,
#    'DARTS_RMSLE': nan}],
#  [<TimeSeries (DataArray) (time: 831, component: 1, sample: 1)>
#   array([[[2021482.61878668]],
#
#          [[2017966.28980965]],
#
#          [[2011721.70433292]],
#
#          [[2020043.22587434]],
#
#          [[2030383.01008633]],
#
#          [[2068963.01189615]],
#
#          [[2088950.75194348]],
#
#          [[2076403.00373665]],
#
#          [[2065865.19188336]],
#
#          [[2068124.51134298]],
#
#   ...
#
#          [[1741151.78382701]],
#
#          [[1735631.5945224 ]],
#
#          [[1735592.49138357]],
#
#          [[1762289.70477372]],
#
#          [[1761916.47963629]],
#
#          [[1768153.36469433]],
#
#          [[1782284.50250937]],
#
#          [[1769368.39252677]],
#
#          [[1725603.65235124]],
#
#          [[1693733.88813321]]])
#   Coordinates:
#     * time       (time) datetime64[ns] 2017-04-25 2017-04-26 ... 2019-08-03
#     * component  (component) object 'nuclear'
#   Dimensions without coordinates: sample,
#   {'MAPE': 0.1161812190107724,
#    'MAE': 220071.7706232678,
#    'R squared': -0.07241997807474221,
#    'MSE': 68343390033.65001,
#    'RMSE': 261425.68740207993,
#    'RMSLE': 12.473905343906116,
#    'time': 0.13990557299985085,
#    'DARTS_MAPE': 11.61812190107724,
#    'DARTS_MAE': 220071.7706232678,
#    'DARTS_R squared': 0.07241997807474221,
#    'DARTS_RMSE': 261425.68740207993,
#    'DARTS_RMSLE': 0.14025828383540506}]]

# %%
df_acc = pd.DataFrame.from_dict(model_predictions[0][1], orient="index")

for i, m in enumerate(models):
    if i > 0:
        df_tmp = pd.DataFrame.from_dict(model_predictions[i][1], orient="index")
        df_tmp.columns = [str(m)]
        df_acc = pd.concat([df_acc, df_tmp], axis=1)
    i +=1

df_acc.columns = models.keys()
pd.set_option("display.precision",3)
df_acc.style.highlight_min(color="lightgreen", axis=1).highlight_max(color="yellow", axis=1)
# Out:
# <style  type="text/css" >
# #T_9f36f_row0_col2,#T_9f36f_row1_col2,#T_9f36f_row2_col2,#T_9f36f_row3_col2,#T_9f36f_row4_col2,#T_9f36f_row5_col2,#T_9f36f_row6_col0,#T_9f36f_row7_col2,#T_9f36f_row8_col2,#T_9f36f_row9_col3,#T_9f36f_row10_col2,#T_9f36f_row11_col0{
#             background-color:  yellow;
#         }#T_9f36f_row0_col3,#T_9f36f_row1_col1,#T_9f36f_row2_col3,#T_9f36f_row3_col3,#T_9f36f_row4_col3,#T_9f36f_row5_col3,#T_9f36f_row6_col1,#T_9f36f_row7_col3,#T_9f36f_row8_col1,#T_9f36f_row9_col2,#T_9f36f_row10_col3,#T_9f36f_row11_col3{
#             background-color:  lightgreen;
#         }</style><table id="T_9f36f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >prophet</th>        <th class="col_heading level0 col1" >naive</th>        <th class="col_heading level0 col2" >expon</th>        <th class="col_heading level0 col3" >theta</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f36f_level0_row0" class="row_heading level0 row0" >MAPE</th>
#                         <td id="T_9f36f_row0_col0" class="data row0 col0" >0.204</td>
#                         <td id="T_9f36f_row0_col1" class="data row0 col1" >0.119</td>
#                         <td id="T_9f36f_row0_col2" class="data row0 col2" >1.644</td>
#                         <td id="T_9f36f_row0_col3" class="data row0 col3" >0.116</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row1" class="row_heading level0 row1" >MAE</th>
#                         <td id="T_9f36f_row1_col0" class="data row1 col0" >351256.858</td>
#                         <td id="T_9f36f_row1_col1" class="data row1 col1" >214189.624</td>
#                         <td id="T_9f36f_row1_col2" class="data row1 col2" >2985826.140</td>
#                         <td id="T_9f36f_row1_col3" class="data row1 col3" >220071.771</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row2" class="row_heading level0 row2" >R squared</th>
#                         <td id="T_9f36f_row2_col0" class="data row2 col0" >1.640</td>
#                         <td id="T_9f36f_row2_col1" class="data row2 col1" >-0.023</td>
#                         <td id="T_9f36f_row2_col2" class="data row2 col2" >151.963</td>
#                         <td id="T_9f36f_row2_col3" class="data row2 col3" >-0.072</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row3" class="row_heading level0 row3" >MSE</th>
#                         <td id="T_9f36f_row3_col0" class="data row3 col0" >194489274552.975</td>
#                         <td id="T_9f36f_row3_col1" class="data row3 col1" >72014089455.639</td>
#                         <td id="T_9f36f_row3_col2" class="data row3 col2" >11270195164525.262</td>
#                         <td id="T_9f36f_row3_col3" class="data row3 col3" >68343390033.650</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row4" class="row_heading level0 row4" >RMSE</th>
#                         <td id="T_9f36f_row4_col0" class="data row4 col0" >441009.381</td>
#                         <td id="T_9f36f_row4_col1" class="data row4 col1" >268354.410</td>
#                         <td id="T_9f36f_row4_col2" class="data row4 col2" >3357111.134</td>
#                         <td id="T_9f36f_row4_col3" class="data row4 col3" >261425.687</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row5" class="row_heading level0 row5" >RMSLE</th>
#                         <td id="T_9f36f_row5_col0" class="data row5 col0" >12.997</td>
#                         <td id="T_9f36f_row5_col1" class="data row5 col1" >12.500</td>
#                         <td id="T_9f36f_row5_col2" class="data row5 col2" >15.027</td>
#                         <td id="T_9f36f_row5_col3" class="data row5 col3" >12.474</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row6" class="row_heading level0 row6" >time</th>
#                         <td id="T_9f36f_row6_col0" class="data row6 col0" >4.912</td>
#                         <td id="T_9f36f_row6_col1" class="data row6 col1" >0.080</td>
#                         <td id="T_9f36f_row6_col2" class="data row6 col2" >0.547</td>
#                         <td id="T_9f36f_row6_col3" class="data row6 col3" >0.140</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row7" class="row_heading level0 row7" >DARTS_MAPE</th>
#                         <td id="T_9f36f_row7_col0" class="data row7 col0" >20.386</td>
#                         <td id="T_9f36f_row7_col1" class="data row7 col1" >11.919</td>
#                         <td id="T_9f36f_row7_col2" class="data row7 col2" >164.402</td>
#                         <td id="T_9f36f_row7_col3" class="data row7 col3" >11.618</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row8" class="row_heading level0 row8" >DARTS_MAE</th>
#                         <td id="T_9f36f_row8_col0" class="data row8 col0" >351256.858</td>
#                         <td id="T_9f36f_row8_col1" class="data row8 col1" >214189.624</td>
#                         <td id="T_9f36f_row8_col2" class="data row8 col2" >2985826.140</td>
#                         <td id="T_9f36f_row8_col3" class="data row8 col3" >220071.771</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row9" class="row_heading level0 row9" >DARTS_R squared</th>
#                         <td id="T_9f36f_row9_col0" class="data row9 col0" >-1.640</td>
#                         <td id="T_9f36f_row9_col1" class="data row9 col1" >0.023</td>
#                         <td id="T_9f36f_row9_col2" class="data row9 col2" >-151.963</td>
#                         <td id="T_9f36f_row9_col3" class="data row9 col3" >0.072</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row10" class="row_heading level0 row10" >DARTS_RMSE</th>
#                         <td id="T_9f36f_row10_col0" class="data row10 col0" >441009.381</td>
#                         <td id="T_9f36f_row10_col1" class="data row10 col1" >268354.410</td>
#                         <td id="T_9f36f_row10_col2" class="data row10 col2" >3357111.134</td>
#                         <td id="T_9f36f_row10_col3" class="data row10 col3" >261425.687</td>
#             </tr>
#             <tr>
#                         <th id="T_9f36f_level0_row11" class="row_heading level0 row11" >DARTS_RMSLE</th>
#                         <td id="T_9f36f_row11_col0" class="data row11 col0" >0.227</td>
#                         <td id="T_9f36f_row11_col1" class="data row11 col1" >0.148</td>
#                         <td id="T_9f36f_row11_col2" class="data row11 col2" >nan</td>
#                         <td id="T_9f36f_row11_col3" class="data row11 col3" >0.140</td>
#             </tr>
#     </tbody></table>

# %%
print(col.center(50, "_"))

plt.figure(figsize=(12, 5))
train.plot(label='training')
val.plot(label='validation')
plt.legend();

pairs = math.ceil(len(models)/2)                    # how many rows of charts
fig, ax = plt.subplots(pairs, 2, figsize=(20, 5 * pairs))
ax = ax.ravel()

for i,m in enumerate(models):
      series.plot(label="actual", ax=ax[i])
      model_predictions[i][0].plot(label="prediction: "+str(m), ax=ax[i])
      
      mape_model =  model_predictions[i][1]["MAPE"]
      time_model =  model_predictions[i][1]["time"]
      ax[i].set_title("\n\n" + str(m) + f": MAPE {str(mape_model)}%" + " - time {:.2f}sec".format(time_model))

      ax[i].set_xlabel("")
      ax[i].legend()
df_acc.style.highlight_min(color="lightgreen", axis=1).highlight_max(color="yellow", axis=1)
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# _____________________nuclear______________________
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# <style  type="text/css" >
# #T_e9843_row0_col2,#T_e9843_row1_col2,#T_e9843_row2_col2,#T_e9843_row3_col2,#T_e9843_row4_col2,#T_e9843_row5_col2,#T_e9843_row6_col0,#T_e9843_row7_col2,#T_e9843_row8_col2,#T_e9843_row9_col3,#T_e9843_row10_col2,#T_e9843_row11_col0{
#             background-color:  yellow;
#         }#T_e9843_row0_col3,#T_e9843_row1_col1,#T_e9843_row2_col3,#T_e9843_row3_col3,#T_e9843_row4_col3,#T_e9843_row5_col3,#T_e9843_row6_col1,#T_e9843_row7_col3,#T_e9843_row8_col1,#T_e9843_row9_col2,#T_e9843_row10_col3,#T_e9843_row11_col3{
#             background-color:  lightgreen;
#         }</style><table id="T_e9843_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >prophet</th>        <th class="col_heading level0 col1" >naive</th>        <th class="col_heading level0 col2" >expon</th>        <th class="col_heading level0 col3" >theta</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e9843_level0_row0" class="row_heading level0 row0" >MAPE</th>
#                         <td id="T_e9843_row0_col0" class="data row0 col0" >0.204</td>
#                         <td id="T_e9843_row0_col1" class="data row0 col1" >0.119</td>
#                         <td id="T_e9843_row0_col2" class="data row0 col2" >1.644</td>
#                         <td id="T_e9843_row0_col3" class="data row0 col3" >0.116</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row1" class="row_heading level0 row1" >MAE</th>
#                         <td id="T_e9843_row1_col0" class="data row1 col0" >351256.858</td>
#                         <td id="T_e9843_row1_col1" class="data row1 col1" >214189.624</td>
#                         <td id="T_e9843_row1_col2" class="data row1 col2" >2985826.140</td>
#                         <td id="T_e9843_row1_col3" class="data row1 col3" >220071.771</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row2" class="row_heading level0 row2" >R squared</th>
#                         <td id="T_e9843_row2_col0" class="data row2 col0" >1.640</td>
#                         <td id="T_e9843_row2_col1" class="data row2 col1" >-0.023</td>
#                         <td id="T_e9843_row2_col2" class="data row2 col2" >151.963</td>
#                         <td id="T_e9843_row2_col3" class="data row2 col3" >-0.072</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row3" class="row_heading level0 row3" >MSE</th>
#                         <td id="T_e9843_row3_col0" class="data row3 col0" >194489274552.975</td>
#                         <td id="T_e9843_row3_col1" class="data row3 col1" >72014089455.639</td>
#                         <td id="T_e9843_row3_col2" class="data row3 col2" >11270195164525.262</td>
#                         <td id="T_e9843_row3_col3" class="data row3 col3" >68343390033.650</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row4" class="row_heading level0 row4" >RMSE</th>
#                         <td id="T_e9843_row4_col0" class="data row4 col0" >441009.381</td>
#                         <td id="T_e9843_row4_col1" class="data row4 col1" >268354.410</td>
#                         <td id="T_e9843_row4_col2" class="data row4 col2" >3357111.134</td>
#                         <td id="T_e9843_row4_col3" class="data row4 col3" >261425.687</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row5" class="row_heading level0 row5" >RMSLE</th>
#                         <td id="T_e9843_row5_col0" class="data row5 col0" >12.997</td>
#                         <td id="T_e9843_row5_col1" class="data row5 col1" >12.500</td>
#                         <td id="T_e9843_row5_col2" class="data row5 col2" >15.027</td>
#                         <td id="T_e9843_row5_col3" class="data row5 col3" >12.474</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row6" class="row_heading level0 row6" >time</th>
#                         <td id="T_e9843_row6_col0" class="data row6 col0" >4.912</td>
#                         <td id="T_e9843_row6_col1" class="data row6 col1" >0.080</td>
#                         <td id="T_e9843_row6_col2" class="data row6 col2" >0.547</td>
#                         <td id="T_e9843_row6_col3" class="data row6 col3" >0.140</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row7" class="row_heading level0 row7" >DARTS_MAPE</th>
#                         <td id="T_e9843_row7_col0" class="data row7 col0" >20.386</td>
#                         <td id="T_e9843_row7_col1" class="data row7 col1" >11.919</td>
#                         <td id="T_e9843_row7_col2" class="data row7 col2" >164.402</td>
#                         <td id="T_e9843_row7_col3" class="data row7 col3" >11.618</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row8" class="row_heading level0 row8" >DARTS_MAE</th>
#                         <td id="T_e9843_row8_col0" class="data row8 col0" >351256.858</td>
#                         <td id="T_e9843_row8_col1" class="data row8 col1" >214189.624</td>
#                         <td id="T_e9843_row8_col2" class="data row8 col2" >2985826.140</td>
#                         <td id="T_e9843_row8_col3" class="data row8 col3" >220071.771</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row9" class="row_heading level0 row9" >DARTS_R squared</th>
#                         <td id="T_e9843_row9_col0" class="data row9 col0" >-1.640</td>
#                         <td id="T_e9843_row9_col1" class="data row9 col1" >0.023</td>
#                         <td id="T_e9843_row9_col2" class="data row9 col2" >-151.963</td>
#                         <td id="T_e9843_row9_col3" class="data row9 col3" >0.072</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row10" class="row_heading level0 row10" >DARTS_RMSE</th>
#                         <td id="T_e9843_row10_col0" class="data row10 col0" >441009.381</td>
#                         <td id="T_e9843_row10_col1" class="data row10 col1" >268354.410</td>
#                         <td id="T_e9843_row10_col2" class="data row10 col2" >3357111.134</td>
#                         <td id="T_e9843_row10_col3" class="data row10 col3" >261425.687</td>
#             </tr>
#             <tr>
#                         <th id="T_e9843_level0_row11" class="row_heading level0 row11" >DARTS_RMSLE</th>
#                         <td id="T_e9843_row11_col0" class="data row11 col0" >0.227</td>
#                         <td id="T_e9843_row11_col1" class="data row11 col1" >0.148</td>
#                         <td id="T_e9843_row11_col2" class="data row11 col2" >nan</td>
#                         <td id="T_e9843_row11_col3" class="data row11 col3" >0.140</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## b) forecast

# %%
# prepare Theta forecaster

# search space for best theta value: check 100 alternatives
thetas = 2 - np.linspace(-10, 10, 100)

# initialize search
best_mape = float('inf')
best_theta = 0
# search for best theta among 50 values, as measured by MAPE
for theta in thetas:
    model = Theta(theta)
    res = model.fit(train)
    pred_theta = model.predict(len(val))
    # res_mape = mape(val, pred_theta)
    res_mape = rmsle(val, pred_theta)
    # res_mape = mean_absolute_percentage_error(val, pred_theta)

    if res_mape < best_mape:
        best_mape = res_mape
        best_theta = theta

m_theta_forecast = Theta(best_theta)   # best theta model among 100

m_prophet_forecast = Prophet()

def forecast_model(model, data, nb_pred):
    print("beginning: " + str(model))


    # fit the model and compute predictions
    res = model.fit(data)
    forecast = model.predict(nb_pred)
    
    return forecast

models_forecast = {"prophet": m_theta_forecast, "theta": m_prophet_forecast}

model_predictions = [forecast_model(v, series, 10000) for k, v in models_forecast.items()]

plt.figure(figsize=(20, 7))
for i,m in enumerate(models_forecast.keys()):
      print(i, m)
      plt.subplot(1, 2, i + 1)
      plt.title(m)
      series.plot(label="actual")
      model_predictions[i].plot()
plt.show()
# Out:
# [2021-10-21 16:49:28,705] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:28,705] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:28,786] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:28,786] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:28,867] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:28,867] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:28,947] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:28,947] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,028] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,028] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,095] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,095] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,180] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,180] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,262] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,262] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,343] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,343] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,415] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,415] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,510] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,510] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,588] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,588] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,679] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,679] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,754] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,754] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,849] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,849] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:29,929] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:29,929] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,004] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,004] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,081] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,081] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,162] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,162] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,236] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,236] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,305] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,305] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,384] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,384] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,480] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,480] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,569] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,569] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,652] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,652] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,727] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,727] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,795] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,795] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,884] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,884] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:30,965] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:30,965] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,037] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,037] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,119] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,119] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,208] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,208] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,291] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,291] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,375] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,375] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,445] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,445] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,522] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,522] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,603] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,603] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,693] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,693] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,792] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,792] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,874] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,874] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:31,942] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:31,942] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,018] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,018] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,093] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,093] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,165] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,165] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,243] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,243] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,316] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,316] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,410] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,410] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,494] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,494] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,575] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,575] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,651] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,651] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,734] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,734] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,814] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,814] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,899] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,899] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:32,972] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:32,972] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,040] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,040] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,116] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,116] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,195] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,195] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,272] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,272] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,360] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,360] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,432] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,432] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,506] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,506] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,577] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,577] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,658] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,658] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,756] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,756] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,833] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,833] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,913] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,913] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:33,990] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:33,990] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,070] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,070] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,150] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,150] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,228] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,228] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,315] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,315] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,407] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,407] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,494] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,494] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,572] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,572] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,658] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,658] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,735] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,735] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,815] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,815] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,895] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,895] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:34,972] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:34,972] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,054] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,054] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,136] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,136] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,214] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,214] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,292] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,292] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,382] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,382] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,474] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,474] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,554] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,554] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,637] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,637] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,731] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,731] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,822] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,822] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,893] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,893] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:35,977] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:35,977] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:36,065] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:36,065] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:36,139] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:36,139] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:36,221] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:36,221] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:36,304] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:36,304] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:36,388] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:36,388] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:36,479] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:36,479] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:36,563] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:36,563] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:36,645] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:36,645] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:36,714] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# [2021-10-21 16:49:36,714] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 175
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 175
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# [2021-10-21 16:49:36,804] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 85
# [2021-10-21 16:49:36,804] INFO | darts.models.forecasting.theta | Theta model inferred seasonality of training series: 85
# INFO:darts.models.forecasting.theta:Theta model inferred seasonality of training series: 85
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# beginning: Theta(0.08080808080808133)
# beginning: Prophet
# 0 prophet
# 1 theta

# %% [markdown]
# # II. Train & Pred

# %%
from math import sqrt
import os
from tqdm import tqdm

import keras
from keras.utils.vis_utils import plot_model
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Dropout, LSTM, Conv1D, GlobalMaxPooling1D, SimpleRNN

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

from tqdm.keras import TqdmCallback

from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
col = "nuclear"

print(df_raw.shape)
display(df_raw.head())
df_raw.info()
# Out:
# (2772, 6)
#    timestamp          coal       nuclear           wind          hydro  solar
# 0 2012-01-01  2.448325e+06  2.029537e+06  760388.000000  226484.000000    0.0
# 1 2012-01-02  2.938653e+06  2.037884e+06  795531.261324  224000.780488    0.0
# 2 2012-01-03  4.430877e+06  2.005847e+06  621916.000000  231623.000000    0.0
# 3 2012-01-04  4.903744e+06  2.039013e+06  764407.000000  232221.000000    0.0
# 4 2012-01-05  4.765032e+06  2.171748e+06  760181.000000  238301.000000    0.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2772 entries, 0 to 2771
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  2772 non-null   datetime64[ns]
#  1   coal       2772 non-null   float64
#  2   nuclear    2772 non-null   float64
#  3   wind       2772 non-null   float64
#  4   hydro      2772 non-null   float64
#  5   solar      2772 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 151.6 KB

# %%
df = df_raw[["timestamp", col]]
df.set_index(df["timestamp"].values, drop=True, inplace=True)
df.drop("timestamp", axis=1, inplace=True)
df.plot()
plt.show()
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  nuclear
# 2012-01-01  2.029537e+06
# 2012-01-02  2.037884e+06
# 2012-01-03  2.005847e+06
# 2012-01-04  2.039013e+06
# 2012-01-05  2.171748e+06

# %%
decomposition = seasonal_decompose(df)
fig = decomposition.plot();
fig.set_size_inches(21, 9)

# %%
fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

plot_acf(decomposition.seasonal, ax=ax[0])
plot_pacf(decomposition.seasonal, ax=ax[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning:
#
# The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.

# %%
# Divide data into train and test sets
train_split_percent = 0.75

train_split_percent = int(df.shape[0] * train_split_percent)

train = df.iloc[:train_split_percent]
test = df.iloc[train_split_percent:]

# %%
# Normalize training data
sc = MinMaxScaler(feature_range=(0,1))
train_scaled = sc.fit_transform(train)
 
# Create supervised data with 12 inputs and 1 output
n_lag = 30
n_output = 30
X_train = []
y_train = []
for i in range(n_lag, len(train) - n_output):
    X_train.append(train_scaled[i-n_lag:i, 0])
    y_train.append(train_scaled[i:i+n_output, 0])
 
X_train, y_train = np.array(X_train), np.array(y_train)
 
# Reshape train set
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# ## a) train model

# %%
inputs = Input(shape=(X_train.shape[1], 1))

main = Dense(n_lag, activation="relu")(inputs)

main = LSTM(256, activation="tanh", recurrent_activation="sigmoid", return_sequences=True)(main)
# main = LSTM(256, activation="tanh", recurrent_activation="sigmoid", return_sequences=True)(main)
main = LSTM(128, activation="tanh", recurrent_activation="sigmoid", return_sequences=True)(main)
# main = LSTM(64, activation="tanh", recurrent_activation="sigmoid")(main)
# main = LSTM(128, activation="tanh", recurrent_activation="sigmoid")(main)
# main = TCN()(main)
main = LSTM(64, activation="tanh", recurrent_activation="sigmoid")(main)

main = Dense(n_output, activation=None, name='output')(main)

model = Model(inputs, main)

model.summary()

model.compile(
  optimizer = Adam(learning_rate=0.001),
  loss = "mae",
)
plot_model(model, to_file="blbl.png", show_shapes=True)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 30, 1)]           0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30, 30)            60
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 30, 256)           293888
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 30, 128)           197120
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# output (Dense)               (None, 30)                1950
# =================================================================
# Total params: 542,426
# Trainable params: 542,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
if not os.path.isdir("model"):
  os.system("mkdir model")

model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath="model/model.h5",
    mode='max',
    save_best_only=True)

history = model.fit(
      X_train,
      y_train,
      validation_split=0.2,
      epochs=100,
      verbose=0,
      batch_size=16,
      callbacks=[model_checkpoint_callback, TqdmCallback(verbose=2)]
  )

# show loss
loss_per_epoch = model.history.history["loss"]
plt.plot(range(len(loss_per_epoch)), loss_per_epoch)
plt.show()
# Out:
# 0epoch [00:00, ?epoch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]
#   0%|          | 0.00/101 [00:00<?, ?batch/s]

# %% [markdown]
# ## b) predict

# %%
predict = pd.DataFrame(test.values)
predict.columns = [col]
predict.index = test.index
predict
# Out:
#                  nuclear
# 2017-09-10  2.293252e+06
# 2017-09-11  2.293627e+06
# 2017-09-12  2.185045e+06
# 2017-09-13  2.151942e+06
# 2017-09-14  2.139938e+06
# ...                  ...
# 2019-07-30  1.573999e+06
# 2019-07-31  1.606865e+06
# 2019-08-01  1.606940e+06
# 2019-08-02  1.592180e+06
# 2019-08-03  1.567348e+06
#
# [693 rows x 1 columns]

# %% [markdown]
# pred_t+1_from_true_values

# %%
inputs = df[len(df) - len(test) - n_lag:].values

inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(n_lag, n_lag+len(test)):
    X_test.append(inputs[i-n_lag:i, 0])

X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
 
# Forecast
predict_scaled = model.predict(X_test)
pred_tab = []
for tmp in predict_scaled:
  if n_output > 1:
    pred_tab.append(tmp[0])
  else:
    pred_tab.append(tmp)
predict_scaled = sc.inverse_transform(np.reshape(pred_tab, (-1, 1)))

predict['pred_t+1_from_true_values'] = predict_scaled

# %% [markdown]
# pred n_lag by n_lag

# %%
test_predictions = []
first_batch_for_prediction = train_scaled[-n_lag :]
current_batch = first_batch_for_prediction.reshape((1, n_lag, 1))
print(current_batch.shape)
for index in tqdm(range(0, len(predict), n_output)):
    current_prediction = model.predict(current_batch)[0]
    test_predictions += list(current_prediction)
    # current_batch = current_prediction.reshape((1, n_lag, 1))
    if n_lag > n_output:
        n_elements_to_keep = n_lag - n_output
        current_batch[0, :n_elements_to_keep, 0] = current_batch[0, -n_elements_to_keep:, 0]
        current_batch[0, -n_elements_to_keep:, 0] = current_prediction
    else:
        current_batch = current_prediction[-n_lag:].reshape((1, n_lag, 1))
test_predictions = np.array(test_predictions).reshape((-1, 1))
test_predictions_unnormalized = sc.inverse_transform(test_predictions)
predict["pred n_lag by n_lag"] = test_predictions_unnormalized[:len(predict)]
# Out:
# (1, 30, 1)
# 100%|██████████| 24/24 [00:01<00:00, 16.47it/s]

# %%
# test_predictions = []
# first_batch_for_prediction = train_scaled[-n_lag :]
# current_batch = first_batch_for_prediction.reshape((1, n_lag, 1))

# for index in tqdm(range(0, len(test), n_lag)):

#   current_prediction = model.predict(current_batch)[0]

#   test_predictions += list(current_prediction)

#   current_batch = current_prediction.reshape((1, n_lag, 1))

# test_predictions_unnormalized = sc.inverse_transform(np.reshape(test_predictions, (-1, 1)))

# predict["pred n_lag by n_lag"] = test_predictions_unnormalized[:predict.shape[0]]

# %% [markdown]
# pred 1 by 1

# %%
test_predictions = []
first_batch_for_prediction = train_scaled[-n_lag :]
current_batch = first_batch_for_prediction.reshape((1, n_lag, 1))

for index in tqdm(range(0, len(test))):

  current_prediction = model.predict(current_batch)[0][0]

  test_predictions.append(current_prediction)

  current_batch = np.append(current_batch[:, 1:, :], [[[current_prediction]]], axis=1)


test_predictions_unnormalized = sc.inverse_transform(np.reshape(test_predictions, (-1, 1)))

predict["pred 1 by 1"] = test_predictions_unnormalized[:predict.shape[0]]
predict.plot(figsize=(20,10))
# Out:
# 100%|██████████| 693/693 [00:40<00:00, 17.06it/s]
# <AxesSubplot:>

# %% [markdown]
# ## c) Metrics

# %%
for tmp_col in predict.columns:
  if "pred" in tmp_col:
    print("col name:", tmp_col)

    rmse = sqrt(mean_squared_error(predict[col], predict[tmp_col]))
    print("rmse:", rmse)
# Out:
# col name: pred_t+1_from_true_values
# rmse: 108583.34919930258
# col name: pred n_lag by n_lag
# rmse: 342837.8128925422
# col name: pred 1 by 1
# rmse: 370264.4086096585
